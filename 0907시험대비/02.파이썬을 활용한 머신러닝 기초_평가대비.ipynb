# %% [markdown]
# #### IoT사물인터넷 with 라즈베리파이 평가대비문제

# %%
# 코드 작성 전 이 셀을 실행하여 pandas 라이브러리를 import 하세요.
import pandas as pd

# %% [markdown]
# 문제 1. 공유폴더에 제공한 'order.xlsx' 파일을 불러와 DataFrame 데이터를 'df'로 생성

# %%
#문제 1번 풀이 작성
df = pd.read_excel('order.xlsx')
df
# Out:
#       주문번호  고객명  카테고리  지역      판매금액   수량   할인율   평점
# 0   ORD001  김민준  전자제품  서울  120000.0  2.0  10.0  4.5
# 1   ORD002  이서연    의류  부산   45000.0  3.0   0.0  3.8
# 2   ORD003  박지호  전자제품  서울  230000.0  1.0  15.0  NaN
# 3   ORD004  최수아    식품  대구   18000.0  5.0   0.0  4.2
# 4   ORD005  정우진    의류  서울   67000.0  4.0   5.0  4.0
# 5   ORD006  강하은  전자제품  부산  310000.0  1.0  20.0  NaN
# 6   ORD007  윤도현    식품  대구   22000.0  6.0   0.0  3.5
# 7   ORD008  임지유   NaN  서울   89000.0  2.0  10.0  4.7
# 8   ORD009  한준서    의류  부산   54000.0  3.0   5.0  3.9
# 9   ORD010  오서현  전자제품  대구  175000.0  1.0  15.0  4.3
# 10  ORD011  배준혁    식품  서울   31000.0  4.0   0.0  4.1
# 11  ORD012  신하은    의류  부산   48000.0  2.0   NaN  3.7
# 12  ORD013  류지원   NaN  서울   95000.0  3.0  10.0  NaN
# 13  ORD014  문서준  전자제품  대구       NaN  NaN  20.0  4.8
# 14  ORD015  남다인    식품  부산   27000.0  5.0   0.0  4.0

# %% [markdown]
# 문제 2. 컬럼별 결측치의 갯수를 파악하여 결측치의 갯수가 가장 많은 컬럼명을 변수 '답_02'에 저장하세요.
# ex> 답_02 = '컬럼1'
# ex> 답_02 = '컬럼1, 컬럼2'

# %%
#문제 2번 풀이 작성
답_02 =  df.isnull().sum().idxmax()
답_02
# Out:
# '평점'

# %% [markdown]
# 문제 3. df 데이터를 아래 기준으로 결측치를 처리하세요. 처리된 결과는 df에 저장되어야 합니다.
# 1) 카테고리 컬럼 -> '미분류'로 채우기
# 2) 한인율 -> 0으로 채우기
# 3) 판매금액 -> 평균값으로 채우기
# 4) 수량 -> 중앙값으로 채우기
# 5) 평점 -> 평균값으로 채우기(소수점 둘째 자리)

# %%
#문제 3번 풀이 작성
df.fillna({'카테고리':'미분류', '할인율':0, '판매금액':df['판매금액'].mean(),'수량':df['수량'].median(), '평점':round(df['평점'].mean(),2)})
# Out:
#       주문번호  고객명  카테고리  지역           판매금액   수량   할인율    평점      총판매액
# 0   ORD001  김민준  전자제품  서울  120000.000000  2.0  10.0  4.50  240000.0
# 1   ORD002  이서연    의류  부산   45000.000000  3.0   0.0  3.80  135000.0
# 2   ORD003  박지호  전자제품  서울  230000.000000  1.0  15.0  4.12  230000.0
# 3   ORD004  최수아    식품  대구   18000.000000  5.0   0.0  4.20   90000.0
# 4   ORD005  정우진    의류  서울   67000.000000  4.0   5.0  4.00  268000.0
# 5   ORD006  강하은  전자제품  부산  310000.000000  1.0  20.0  4.12  310000.0
# 6   ORD007  윤도현    식품  대구   22000.000000  6.0   0.0  3.50  132000.0
# 7   ORD008  임지유   미분류  서울   89000.000000  2.0  10.0  4.70  178000.0
# 8   ORD009  한준서    의류  부산   54000.000000  3.0   5.0  3.90  162000.0
# 9   ORD010  오서현  전자제품  대구  175000.000000  1.0  15.0  4.30  175000.0
# 10  ORD011  배준혁    식품  서울   31000.000000  4.0   0.0  4.10  124000.0
# 11  ORD012  신하은    의류  부산   48000.000000  2.0   0.0  3.70   96000.0
# 12  ORD013  류지원   미분류  서울   95000.000000  3.0  10.0  4.12  285000.0
# 13  ORD014  문서준  전자제품  대구   95071.428571  3.0  20.0  4.80       NaN
# 14  ORD015  남다인    식품  부산   27000.000000  5.0   0.0  4.00  135000.0

# %% [markdown]
# 문제 4. df에서 '카테고리'와 '지역' 컬럼만 선택하여 출력하세요.

# %%
#문제 4번 풀이 작성
df[['카테고리','지역']]
# Out:
#     카테고리  지역
# 0   전자제품  서울
# 1     의류  부산
# 2   전자제품  서울
# 3     식품  대구
# 4     의류  서울
# 5   전자제품  부산
# 6     식품  대구
# 7    NaN  서울
# 8     의류  부산
# 9   전자제품  대구
# 10    식품  서울
# 11    의류  부산
# 12   NaN  서울
# 13  전자제품  대구
# 14    식품  부산

# %% [markdown]
# 문제 5. df에서 지역이 '서울'이거나 '부산'인 주문 중 평점이 4.0 이상이 주문 정보를 출력하세요.

# %%
#문제 5번 풀이 작성
df[((df['지역']=='서울')|(df['지역'] =='부산')) & (df['평점']>=4.0)]
# Out:
#       주문번호  고객명  카테고리  지역      판매금액   수량   할인율   평점
# 0   ORD001  김민준  전자제품  서울  120000.0  2.0  10.0  4.5
# 4   ORD005  정우진    의류  서울   67000.0  4.0   5.0  4.0
# 7   ORD008  임지유   NaN  서울   89000.0  2.0  10.0  4.7
# 10  ORD011  배준혁    식품  서울   31000.0  4.0   0.0  4.1
# 14  ORD015  남다인    식품  부산   27000.0  5.0   0.0  4.0

# %% [markdown]
# 문제 6. df 데이터를 아래 요구사항에 맞게 데이터를 변경하세요.
# 1) '판매금액'과 '수량'을 곱한 '총판매액' 컬럼을 추가하세요
# 2) '지역'컬럼에서 '대구'를 '대구광역시'로 변경하세요.

# %%
#문제 6번 풀이 작성
df['총판매액'] = df['판매금액'] * df['수량']
df.replace('대구','대구광역시')
# Out:
#       주문번호  고객명  카테고리     지역      판매금액   수량   할인율   평점      총판매액
# 0   ORD001  김민준  전자제품     서울  120000.0  2.0  10.0  4.5  240000.0
# 1   ORD002  이서연    의류     부산   45000.0  3.0   0.0  3.8  135000.0
# 2   ORD003  박지호  전자제품     서울  230000.0  1.0  15.0  NaN  230000.0
# 3   ORD004  최수아    식품  대구광역시   18000.0  5.0   0.0  4.2   90000.0
# 4   ORD005  정우진    의류     서울   67000.0  4.0   5.0  4.0  268000.0
# 5   ORD006  강하은  전자제품     부산  310000.0  1.0  20.0  NaN  310000.0
# 6   ORD007  윤도현    식품  대구광역시   22000.0  6.0   0.0  3.5  132000.0
# 7   ORD008  임지유   NaN     서울   89000.0  2.0  10.0  4.7  178000.0
# 8   ORD009  한준서    의류     부산   54000.0  3.0   5.0  3.9  162000.0
# 9   ORD010  오서현  전자제품  대구광역시  175000.0  1.0  15.0  4.3  175000.0
# 10  ORD011  배준혁    식품     서울   31000.0  4.0   0.0  4.1  124000.0
# 11  ORD012  신하은    의류     부산   48000.0  2.0   NaN  3.7   96000.0
# 12  ORD013  류지원   NaN     서울   95000.0  3.0  10.0  NaN  285000.0
# 13  ORD014  문서준  전자제품  대구광역시       NaN  NaN  20.0  4.8       NaN
# 14  ORD015  남다인    식품     부산   27000.0  5.0   0.0  4.0  135000.0

# %% [markdown]
# 문제 7. df 데이터에서 카테고리별 판매금액의 합계를 출력하시오.

# %%
#문제 7번 풀이 작성
df.groupby('카테고리')['판매금액'].sum()
# Out:
# 카테고리
# 식품       98000.0
# 의류      214000.0
# 전자제품    835000.0
# Name: 판매금액, dtype: float64

# %% [markdown]
# 문제 8. 판매금액 기준 내림차순으로 정렬하고, 상위 5개 주문의 고객명과 판매금액을 출력하세요.

# %%
#문제 8번 풀이 작성
df.sort_values(by=['판매금액'], ascending=[False])
df[['고객명','판매금액']].head()
# Out:
#    고객명      판매금액
# 0  김민준  120000.0
# 1  이서연   45000.0
# 2  박지호  230000.0
# 3  최수아   18000.0
# 4  정우진   67000.0
