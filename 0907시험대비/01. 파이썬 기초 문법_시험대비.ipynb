# %% [markdown]
# ### 파이썬 기초 문법 평가 대비

# %% [markdown]
# 1. 키보드로 세 수를 입력받고,입력받은 세 수를 리스트에 저장하시오. 그 후 리스트에 저장된 수 중 가장 큰 수와 가장 작은 수의 차를 출력하시오.

# %%
#1번 문제 풀이 작성
num1 = int(input('첫번째 정수 입력 :'))
num2 = int(input('두번째 정수 입력 :'))
num3 = int(input('세번째 정수 입력 :'))

list1 = [num1,num2,num3]
print(max(list1) - min(list1))
# Out:
# 9

# %% [markdown]
# 2. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 저장된 모든 데이터의 합을 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,2,3] , [4,5,6] / 결과 : 21

# %%
#2번 문제 풀이 작성
list2 = [1,2,3]
list3 = [4,5,6]
def total1(a,b):
  list4 = a + b
  return sum(list4)
total1(list2,list3)
# Out:
# 21

# %% [markdown]
# 3. 매개변수로 두 개의 리스트를 받아, 두 개의 리스트에 중복으로 저장된 데이터만을 갖는  새로운 리스트를 리턴하는 함수를 작성하시오.
# EX> 두 매개변수 : [1,3,5,7,9] , [1,2,3,4,5] / 결과 : [1,3,5]

# %%
#3번 문제 풀이 작성
list5 = [1,3,5,7,9]
list6 = [1,2,3,4,5]

def duplicate1(a,b):
  list7 = []
  for e in a:
    for f in b:
      if(e == f):
        list7.append(e)
  return list7      

duplicate1(list5, list6)
# Out:
# [1, 3, 5]

# %% [markdown]
# 4. 이름, 나이, 국어점수, 영어점수, 국어점수를 데이터로 갖는 student 딕셔너리를 만드시오. 각 데이터는 키보드로 입력받아 저장하시오.

# %%
#4번 문제 풀이 작성
name1 = input('이름을 입력하시오. :')
age1 = int(input('나이를 입력하시오. :'))
kor_score = int(input('국어 점수를 입력하시오. :')) 
eng_score = int(input('영어 점수를 입력하시오. :')) 
math_score = int(input('수학 점수를 입력하시오. :')) 

student = {'name':name1, 'age':age1, 'kor': kor_score, 'eng' : eng_score, 'math' : math_score }

print(student)
# Out:
# {'name': '김성준', 'age': 30, 'kor': 90, 'eng': 80, 'math': 70}

# %% [markdown]
# 5. 4번 문제에서 만든 딕셔너리 데이터에 총점 데이터를 추가하시오. 총점 데이터는 국어,영어, 수학점수의 합으로 들어가야합니다.

# %%
#5번 문제 풀이 작성
student['total'] = kor_score + eng_score + math_score
print(student)
# Out:
# {'name': '김성준', 'age': 30, 'kor': 90, 'eng': 80, 'math': 70, 'total': 240}

# %% [markdown]
# 6. 아래 딕셔너리 데이터에 stu_grade라는 키를 추가하고, 해당 키의  데이터로  점수(stu_score)에 따른 등급 데이터를 저장하시오.
# 90 <= 점수      : A등급
# 80 <= 점수 < 90 : B등급
# 70 <= 점수 < 80 : C등급
#       점수 < 70 : D등급

# %%
class_room_data = {
  'stu_no' : [1, 2, 3, 4, 5],
  'stu_name' : ['김자바', '이자바', '박자바', '최자바', '정자바'],
  'stu_score' : [85, 65, 70, 80, 95]
}

#6번 문제 풀이 작성
class_room_data['stu_grade'] = []

for e in class_room_data['stu_score']:
  if e >= 90 :
    class_room_data['stu_grade'].append('A')
  elif e >= 80 :
    class_room_data['stu_grade'].append('B')
  elif e >= 70 :
    class_room_data['stu_grade'].append('C')
  else :
    class_room_data['stu_grade'].append('D')

print(class_room_data['stu_grade'])
# Out:
# ['B', 'D', 'C', 'B', 'A']
